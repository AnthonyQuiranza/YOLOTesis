# %% [markdown]
# Descomprimimos el dataset específico para YOLOV5

# %%
# !unzip dataset.zip

# %% [markdown]
# Importamos el modelo de YOLO

# %%
# !git clone https://github.com/ultralytics/yolov5

# %% [markdown]
# Instalamos las librerías que requiere el sistema.

# %%
# !pip install -r yolov5/requirements.txt

# %% [markdown]
# Ejecutamos el entrenamiento
# --epochs se refiere a el número de veces que el algoritmo va a analizar los datos.

# %%
# !python yolov5/train.py --data yolov5/data.yaml --cfg yolov5s.yaml --batch-size 8 --name Model --epochs 100
# Out:
# train: weights=yolov5/yolov5s.pt, cfg=yolov5s.yaml, data=yolov5/data.yaml, hyp=yolov5/data/hyps/hyp.scratch.yaml, epochs=100, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=Model, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-214-g3b7ac28 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python yolov5/detectar.py --source yolov5/dataset/test/images/prueba.jpg --weights yolov5/runs/train/Model2/weights/best.pt
# Out:
# detectar: weights=['yolov5/runs/train/Model2/weights/best.pt'], source=yolov5/dataset/test/images/prueba.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.05, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-214-g3b7ac28 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/dataset/test/images/prueba.jpg: 640x640 1 Hoja, Done. (0.033s)
# Speed: 0.7ms pre-process, 33.3ms inference, 2.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp2
